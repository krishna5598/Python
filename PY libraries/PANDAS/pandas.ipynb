# %%
import pandas as pd

# %%
d = pd.read_csv(r'C:\Users\V Krishna Teja\Downloads\archive\covid.csv')
df = pd.DataFrame(d)
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.tail()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 31            99.51         0.49    69599762
# 32            99.13         0.87     1646050
# 33            98.89         1.11     1158040
# 34            98.28         1.72    85002417
# 35            98.98         1.01    32199722

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.249975e+06    50.333333  1.235146e+06   14778.527778      0.005000
# std    1.846038e+06   207.118048  1.820328e+06   27221.140636      0.026673
# min    1.076600e+04     0.000000  1.063700e+04       4.000000      0.000000
# 25%    1.065430e+05     0.000000  1.055395e+05    1124.250000      0.000000
# 50%    6.140910e+05     1.500000  6.076750e+05    6551.000000      0.000000
# 75%    1.331951e+06     9.000000  1.322329e+06   14325.750000      0.000000
# max    8.171048e+06  1233.000000  8.022276e+06  148558.000000      0.160000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.897222     1.097778  3.971861e+07
# std           0.506854     0.494791  5.050913e+07
# min          97.410000     0.030000  6.600100e+04
# ...

# %%
df.shape
# Out:
# (36, 9)

# %%
df[0:10:2]
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 4                Bihar       855267       1      842952   12314           0.0
# 6         Chhattisgarh      1187695       0     1173505   14190           0.0
# 8                Delhi      2040910      14     2014230   26666           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 2            99.56         0.44      658019
# 4            98.56         1.44    40100376
# 6            98.81         1.19    28900667
# 8            98.69         1.31      773997

# %%
df['Discharged']
# Out:
# 0       10637
# 1     2325943
# 2       66753
# 3      738119
# 4      842952
# 5       99508
# 6     1173505
# 7       11588
# 8     2014230
# 9      259329
# 10    1280299
# 11    1068121
# 12     318660
# 13     477231
# 14     438491
# 15    4048399
# 16    6835181
# 17      29371
# 18      11363
# 19    1045565
# 20    8022276
# 21     137885
# 22      95352
# 23     238825
# 24      35251
# 25    1339135
# 26     175566
# 27     773073
# 28    1316727
# 29      44422
# 30    3572569
# 31     840313
# 32     107550
# 33    2121662
# 34     444803
# 35    2104592
# Name: Discharged, dtype: int64

# %%
df[['Discharged','State/UTs']]
# Out:
#     Discharged                                 State/UTs
# 0        10637                       Andaman and Nicobar
# 1      2325943                            Andhra Pradesh
# 2        66753                         Arunachal Pradesh
# 3       738119                                     Assam
# 4       842952                                     Bihar
# 5        99508                                Chandigarh
# 6      1173505                              Chhattisgarh
# 7        11588  Dadra and Nagar Haveli and Daman and Diu
# 8      2014230                                     Delhi
# 9       259329                                       Goa
# 10     1280299                                   Gujarat
# 11     1068121                                   Haryana
# 12      318660                          Himachal Pradesh
# 13      477231                         Jammu and Kashmir
# 14      438491                                 Jharkhand
# ...

# %%
df[['Discharged','State/UTs']][0:20]
# Out:
#     Discharged                                 State/UTs
# 0        10637                       Andaman and Nicobar
# 1      2325943                            Andhra Pradesh
# 2        66753                         Arunachal Pradesh
# 3       738119                                     Assam
# 4       842952                                     Bihar
# 5        99508                                Chandigarh
# 6      1173505                              Chhattisgarh
# 7        11588  Dadra and Nagar Haveli and Daman and Diu
# 8      2014230                                     Delhi
# 9       259329                                       Goa
# 10     1280299                                   Gujarat
# 11     1068121                                   Haryana
# 12      318660                          Himachal Pradesh
# 13      477231                         Jammu and Kashmir
# 14      438491                                 Jharkhand
# ...

# %%
df[['Discharged','State/UTs']][0:20:4]
# Out:
#     Discharged            State/UTs
# 0        10637  Andaman and Nicobar
# 4       842952                Bihar
# 8      2014230                Delhi
# 12      318660     Himachal Pradesh
# 16     6835181               Kerala

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, State/UTs          Andaman and Nicobar
# Total Cases                      10766
# Active                               0
# Discharged                       10637
# Deaths                             129
# Active Ratio                       0.0
# Discharge Ratio                   98.8
# Death Ratio                        1.2
# Population                   100896618
# Name: 0, dtype: object)
# (1, State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object)
# (2, State/UTs          Arunachal Pradesh
# Total Cases                    67049
# Active                             0
# Discharged                     66753
# Deaths                           296
# Active Ratio                     0.0
# ...

# %%
df.loc[1]
# Out:
# State/UTs          Andhra Pradesh
# Total Cases               2340676
# Active                          0
# Discharged                2325943
# Deaths                      14733
# Active Ratio                  0.0
# Discharge Ratio             99.37
# Death Ratio                  0.63
# Population              128500364
# Name: 1, dtype: object

# %%
df.loc[1:4]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2  Arunachal Pradesh        67049       0       66753     296           0.0
# 3              Assam       746159       5      738119    8035           0.0
# 4              Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.loc[23,["Deaths"]]
# Out:
# Deaths    734
# Name: 23, dtype: object

# %%
df.loc[23:26,["Deaths","Active"]]
# Out:
#     Deaths  Active
# 23     734       1
# 24     782       0
# 25    9215      59
# 26    1981       0

# %%
df.loc[23:26,"Deaths":"Death Ratio"]
# Out:
#     Deaths  Active Ratio  Discharge Ratio  Death Ratio
# 23     734           0.0            99.69         0.31
# 24     782           0.0            97.83         2.17
# 25    9215           0.0            99.31         0.68
# 26    1981           0.0            98.88         1.12

# %%
df.iloc[1:4]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2  Arunachal Pradesh        67049       0       66753     296           0.0
# 3              Assam       746159       5      738119    8035           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492

# %%
df.iloc[1:4,0:9]
# Out:
#            State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1     Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2  Arunachal Pradesh        67049       0       66753     296           0.0
# 3              Assam       746159       5      738119    8035           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492

# %%
df.iloc[1,0]
# Out:
# 'Andhra Pradesh'

# %%
df.iloc[1:5,[1,5,6]]
# Out:
#    Total Cases  Active Ratio  Discharge Ratio
# 1      2340676           0.0            99.37
# 2        67049           0.0            99.56
# 3       746159           0.0            98.92
# 4       855267           0.0            98.56

# %%
df.iloc[:,[1,5,6]]
# Out:
#     Total Cases  Active Ratio  Discharge Ratio
# 0         10766          0.00            98.80
# 1       2340676          0.00            99.37
# 2         67049          0.00            99.56
# 3        746159          0.00            98.92
# 4        855267          0.00            98.56
# 5        100693          0.00            98.82
# 6       1187695          0.00            98.81
# 7         11592          0.00            99.97
# 8       2040910          0.00            98.69
# 9        263346          0.00            98.47
# 10      1291383          0.00            99.14
# 11      1078903          0.00            99.00
# 12       322905          0.00            98.69
# 13       482023          0.00            99.01
# 14       443826          0.00            98.80
# 15      4088769          0.00            99.01
# 16      6907241          0.00            98.96
# 17        29602          0.00            99.22
# 18        11415          0.00            99.54
# ...

# %%
df.iloc[[1,2,3],8]
# Out:
# 1    128500364
# 2       658019
# 3       290492
# Name: Population, dtype: int64

# %%
df.sort_values("Deaths")
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 18                               Lakshadweep        11415       0       11363
# 0                        Andaman and Nicobar        10766       0       10637
# 17                                    Ladakh        29602       0       29371
# 2                          Arunachal Pradesh        67049       0       66753
# 29                                    Sikkim        44927       4       44422
# 23                                   Mizoram       239560       1      238825
# 24                                  Nagaland        36033       0       35251
# 32                                   Tripura       108493       1      107550
# 5                                 Chandigarh       100693       0       99508
# 22                                 Meghalaya        96983       3       95352
# ...

# %%
df.sort_values("Deaths",ascending = False)
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 20                               Maharashtra      8171048     214     8022276
# 16                                    Kerala      6907241      18     6835181
# 15                                 Karnataka      4088769      12     4048399
# 30                                Tamil Nadu      3610655       5     3572569
# 8                                      Delhi      2040910      14     2014230
# 33                             Uttar Pradesh      2145431      57     2121662
# 35                               West Bengal      2126282     135     2104592
# 27                                    Punjab       793644    1233      773073
# 1                             Andhra Pradesh      2340676       0     2325943
# 6                               Chhattisgarh      1187695       0     1173505
# 4                                      Bihar       855267       1      842952
# ...

# %%
df.sort_values(["Population","Deaths"])
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 13                         Jammu and Kashmir       482023       0      477231
# 3                                      Assam       746159       5      738119
# 20                               Maharashtra      8171048     214     8022276
# 2                          Arunachal Pradesh        67049       0       66753
# 8                                      Delhi      2040910      14     2014230
# 33                             Uttar Pradesh      2145431      57     2121662
# 23                                   Mizoram       239560       1      238825
# 28                                 Rajasthan      1326465       2     1316727
# 32                                   Tripura       108493       1      107550
# 15                                 Karnataka      4088769      12     4048399
# 26                                Puducherry       177547       0      175566
# ...

# %%
df.sort_values(["Population","Deaths"],ascending=[1,2])
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 13                         Jammu and Kashmir       482023       0      477231
# 3                                      Assam       746159       5      738119
# 20                               Maharashtra      8171048     214     8022276
# 2                          Arunachal Pradesh        67049       0       66753
# 8                                      Delhi      2040910      14     2014230
# 33                             Uttar Pradesh      2145431      57     2121662
# 23                                   Mizoram       239560       1      238825
# 28                                 Rajasthan      1326465       2     1316727
# 32                                   Tripura       108493       1      107550
# 15                                 Karnataka      4088769      12     4048399
# 26                                Puducherry       177547       0      175566
# ...

# %%
df["Total"]=0
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df["Total"]=df["Population"]-df["Deaths"]

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.drop(columns="Total")
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.drop(columns="Total",inplace=True)

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %%
df.loc[df["Deaths"]>1000]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1      Andhra Pradesh      2340676       0     2325943   14733          0.00
# 3               Assam       746159       5      738119    8035          0.00
# 4               Bihar       855267       1      842952   12314          0.00
# 5          Chandigarh       100693       0       99508    1185          0.00
# 6        Chhattisgarh      1187695       0     1173505   14190          0.00
# 8               Delhi      2040910      14     2014230   26666          0.00
# 9                 Goa       263346       3      259329    4014          0.00
# 10            Gujarat      1291383       5     1280299   11079          0.00
# 11            Haryana      1078903      27     1068121   10755          0.00
# 12   Himachal Pradesh       322905       4      318660    4241          0.00
# 13  Jammu and Kashmir       482023       0      477231    4792          0.00
# ...

# %%
df.loc[(df["Deaths"]>1000) & (df["Population"]<1000000)]
# Out:
#             State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 3               Assam       746159       5      738119    8035           0.0
# 8               Delhi      2040910      14     2014230   26666           0.0
# 13  Jammu and Kashmir       482023       0      477231    4792           0.0
# 20        Maharashtra      8171048     214     8022276  148558           0.0
#
#     Discharge Ratio  Death Ratio  Population
# 3             98.92         1.08      290492
# 8             98.69         1.31      773997
# 13            99.01         0.99       66001
# 20            98.18         1.82      399001

# %%
df.loc[df["State/UTs"].str.contains("i")]
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 12                          Himachal Pradesh       322905       4      318660
# 13                         Jammu and Kashmir       482023       0      477231
# 21                                   Manipur       140034       0      137885
# 23                                   Mizoram       239560       1      238825
# 25                                    Odisha      1348409      59     1339135
# ...
